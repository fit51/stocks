# %% [markdown]
# # Statistic Analysis

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
from time import time

# %%
import os
def symbol_to_path(symbol, base_dir="data"):
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))
# dates = pd.date_range('2010-01-01', '2010-12-31')
# symbols = ['GOOG','IBM','GLD']
def get_data(symbols, dates):
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')
    print(symbols)
    for symbol in symbols:
        df_temp=pd.read_csv(symbol_to_path(symbol), index_col="Date", 
                     parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp=df_temp.rename(columns={'Adj Close': symbol})
        if symbol == 'SPY':
            df=df.join(df_temp, how='inner')
        else:
            df=df.join(df_temp)

    return df
# Notebook setting plot size
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
def normalize_data(df):
    return df/df.ix[0]
def plot_data(df, title="Stock Prices"):
    ax = df.plot(title=title, fontsize=10)
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.show()
def plot_selected(df, columns, start_index, end_index):
    df = df.ix[start_index:end_index, columns]
    plot_data(df)
# plot_selected(df, ['SPY', 'IBM'], '2010-03-01', '2010-04-01')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Mean, Median, Standard Deviation

# %%
dates = pd.date_range('2010-01-01', '2010-12-31')
symbols = ['SPY', 'GOOG', 'GLD']
df = get_data(symbols, dates)
plot_data(df)
print("-----MEAN\n" + str(df.mean()))
print("-----MEDIAN\n" + str(df.median()))
print("-----STD\n" + str(df.std()))
# Out:
# ['SPY', 'GOOG', 'GLD']
# -----MEAN
# SPY      98.342140
# GOOG    266.080947
# GLD     120.069762
# dtype: float64
# -----MEDIAN
# SPY      97.594398
# GOOG    265.433609
# GLD     118.754998
# dtype: float64
# -----STD
# SPY      5.103005
# GOOG    25.067321
# GLD      9.537110
# dtype: float64

# %% [markdown]
# # Moving Statistics(Rolling), Bollinger Bands

# %%
#rolling_mean params - window
dates = pd.date_range('2012-01-01', '2012-12-31')
symbols = ['SPY']
df = get_data(symbols, dates)

def bollinge_bonds(df):
    rm_SPY = pd.Series.rolling(df, window=20).mean()
    rstd_SPY = pd.Series.rolling(df, window=20).std()
    up_bond = rm_SPY + (2*rstd_SPY)
    down_bond = rm_SPY - (2*rstd_SPY)
    return rm_SPY, up_bond, down_bond

df['rm_SPY'], df['Up_Band_SPY'], df['Down_Band_SPY'] = bollinge_bonds(df['SPY'])
plot_data(df, title= "SPY Bollinge Bands")
# Out:
# ['SPY']

# %% [markdown]
# # Dayily Returns

# %%
#dayly rets
dates = pd.date_range('2012-01-01', '2012-12-31')
symbols = ['SPY']
df = get_data(symbols, dates)
print(len(df['SPY']))
daily_returns = df.copy
df[0:1]
# Out:
# ['SPY']
# 250
#                    SPY
# 2012-01-03  113.410439

# %%
#dayly rets
dates = pd.date_range('2012-01-01', '2012-12-31')
symbols = ['SPY']
df = get_data(symbols, dates)
print(len(df['SPY']))
def daily_returns(df):
    daily_returns = df.copy
    daily_returns[1:] = (df[1:] / df[:-1].values) - 1
    daily_returns.ix[0, :] = 0 #row 0 to 0
    df.values = daily_returns
    return df
daily_SPY = {'Daily_Return_SPY': daily_returns(df['SPY'])}
print(daily_SPY)
plot_data(daily_SPY, title='Daily Returns')
# Out:
# ['SPY']
# 250
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-479676cea3ce> in <module>()
#       9     df.values = daily_returns
#      10     return df
# ---> 11 daily_SPY = {'Daily_Return_SPY': daily_returns(df['SPY'])}
#      12 print(daily_SPY)
#      13 plot_data(daily_SPY, title='Daily Returns')
#
# <ipython-input-32-479676cea3ce> in daily_returns(df)
#       6 def daily_returns(df):
#       7     daily_returns = df.copy
# ----> 8     daily_returns[1:] = (df[1:] / df[:-1].values) - 1
#       9     df.values = daily_returns
#      10     return df
#
# TypeError: 'method' object does not support item assignment
